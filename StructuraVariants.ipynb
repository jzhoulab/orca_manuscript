# %%
import sys
sys.path.append("../orca/")

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import orca_predict
#The default is using GPU. Set use_cuda = False in load_resources to use CPU (slow).
orca_predict.load_resources(models=['256M','32M'])
from orca_predict import *

# %%
mkdir -p ./svs

# %%
# %%capture
outputs = process_inv('chr6', 10355047,98655997, hg38, file='./svs/chr6_10355047_98655997_inv_bofs_tfap2a')

outputs = process_dup('chr17', 70845859, 71884859, hg38, file='./svs/chr17_70845859_71884859_RevSex_dup_maximum_Sox9')
outputs = process_dup('chr17', 71410859,71634859, hg38, file='./svs/chr17_71410859_71634859_RevSex_dup_minimum_Sox9')
outputs = process_dup('chr17', 70181859, 71970859, hg38, file='./svs/chr17_70181859_71970859_dup_Nopheno')
outputs = process_dup('chr17', 70126859,71579859, hg38, file='./svs/chr17_70126859_71579859_dup_Cook_minimum_Kcnj2')
outputs = process_dup('chr17', 69986859,71970859, hg38, file='./svs/chr17_69986859_71970859_dup_Cook_maximum_Kcnj2')


outputs = process_del('chr2', 220295000, 222000000, hg38, file='./svs/chr2_220295000_222000000_del_Brachydactyly_Pax3')

outputs = process_inv('chr2', 218875000, 220155000, hg38, file='./svs/chr2_218875000_220155000_inv_FsyndromeF1_Wnt6')
outputs = process_dup('chr2', 218835000,220405000, hg38, file='./svs/chr2_218835000_220405000_dup_FsyndromeF2_Wnt6')
outputs = process_dup('chr2', 219045000,220085000, hg38, file='./svs/chr2_219045000_220085000_dup_Polydactyly_IHH')

outputs = process_inv('chr3', 128550000,169000000, hg38, file='./svs/chr3_128550000_169000000_inv_Leukemia_EVI1')

outputs = process_del('chr1', 47262830,47263175, hg38, file='./svs/chr1_47262830_47263175_del_TALL_TAL1')
outputs = process_del('chr11',33971015,33997645 , hg38, file='./svs/chr11_33971015,33997645_del_TALL_LMO2')

outputs = process_dup('chr11',2118770,2223770, hg38, file='./svs/chr11_2118770_2223770_dup_pancancer_IGF2')
outputs = process_dup('chrX',108048770,108069770, hg38, file='./svs/chrX_108048770_108069770_dup_pancancer_IRS4')
outputs = process_del('chrX',108406770,108632770, hg38, file='./svs/chrX_108406770_108632770_del_pancancer_IRS4')

# %%
# %%capture
outputs = process_inv('chr6', 10355047,98655997, hg38, window_radius=128000000, file='./svs/chr6_10355047_98655997_inv_bofs_tfap2a')

outputs = process_dup('chr17', 70845859, 71884859, hg38, window_radius=128000000, file='./svs/chr17_70845859_71884859_RevSex_dup_maximum_Sox9')
outputs = process_dup('chr17', 71410859,71634859, hg38, window_radius=128000000, file='./svs/chr17_71410859_71634859_RevSex_dup_minimum_Sox9')
outputs = process_dup('chr17', 70181859, 71970859, hg38, window_radius=128000000, file='./svs/chr17_70181859_71970859_dup_Nopheno')
outputs = process_dup('chr17', 70126859,71579859, hg38, window_radius=128000000, file='./svs/chr17_70126859_71579859_dup_Cook_minimum_Kcnj2')
outputs = process_dup('chr17', 69986859,71970859, hg38, window_radius=128000000, file='./svs/chr17_69986859_71970859_dup_Cook_maximum_Kcnj2')


outputs = process_del('chr2', 220295000, 222000000, hg38, window_radius=128000000, file='./svs/chr2_220295000_222000000_del_Brachydactyly_Pax3')

outputs = process_inv('chr2', 218875000, 220155000, hg38, window_radius=128000000, file='./svs/chr2_218875000_220155000_inv_FsyndromeF1_Wnt6')
outputs = process_dup('chr2', 218835000,220405000, hg38, window_radius=128000000, file='./svs/chr2_218835000_220405000_dup_FsyndromeF2_Wnt6')
outputs = process_dup('chr2', 219045000,220085000, hg38, window_radius=128000000, file='./svs/chr2_219045000_220085000_dup_Polydactyly_IHH')

outputs = process_inv('chr3', 128550000,169000000, hg38, window_radius=128000000, file='./svs/chr3_128550000_169000000_inv_Leukemia_EVI1')

outputs = process_del('chr1', 47262830,47263175, hg38, window_radius=128000000, file='./svs/chr1_47262830_47263175_del_TALL_TAL1')
outputs = process_del('chr11',33971015,33997645 , hg38, window_radius=128000000, file='./svs/chr11_33971015,33997645_del_TALL_LMO2')

outputs = process_dup('chr11',2118770,2223770, hg38, window_radius=128000000, file='./svs/chr11_2118770_2223770_dup_pancancer_IGF2')
outputs = process_dup('chrX',108048770,108069770, hg38, window_radius=128000000, file='./svs/chrX_108048770_108069770_dup_pancancer_IRS4')
outputs = process_del('chrX',108406770,108632770, hg38, window_radius=128000000, file='./svs/chrX_108406770_108632770_del_pancancer_IRS4')
